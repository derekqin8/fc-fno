# %%
import matplotlib.pyplot as plt
import numpy as np

import h5py
import scipy.io

# %%
data = np.load('./Darcy_421_Lshape/piececonst_r421_N1024_L1.npy')

print(data.shape)
# Out:
# (1024, 421, 421)

# %%
idx = 0
plt.subplot(1,2,1)

plt.imshow(data[idx])

plt.subplot(1,2,2)
plt.imshow(data[idx+1])

# %%
a_data = scipy.io.loadmat('Darcy_421_Lshape/piececonst_r421_N1024_smooth1.mat')['coeff']

print(a_data.shape)
# Out:
# (1024, 421, 421)

# %%
idx = 300
plt.subplot(1,2,1)
plt.xticks([],[])
plt.yticks([],[])
plt.imshow(a_data[idx])


plt.subplot(1,2,2)
plt.xticks([],[])
plt.yticks([],[])
plt.imshow(data[idx])
